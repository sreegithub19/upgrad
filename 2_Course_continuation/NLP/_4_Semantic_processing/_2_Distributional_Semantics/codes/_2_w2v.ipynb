# %% [markdown]
# # Word2Vec Tutorial with Gensim

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (4.3.0)
# Requirement already satisfied: scipy>=1.7.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from gensim) (1.9.3)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from gensim) (6.3.0)
# Requirement already satisfied: FuzzyTM>=0.4.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from gensim) (2.0.5)
# Requirement already satisfied: numpy>=1.18.5 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from gensim) (1.23.4)
# Requirement already satisfied: pyfume in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from FuzzyTM>=0.4.0->gensim) (0.2.25)
# Requirement already satisfied: pandas in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from FuzzyTM>=0.4.0->gensim) (1.5.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2022.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2.8.2)
# Requirement already satisfied: simpful in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (2.9.0)
# Requirement already satisfied: fst-pso in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (1.8.1)
# Requirement already satisfied: six>=1.5 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->FuzzyTM>=0.4.0->gensim) (1.16.0)
# Requirement already satisfied: miniful in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim) (0.0.6)
# Requirement already satisfied: requests in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (3.4)
#
# [notice] A new release of pip available: 22.3 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# imports

import json
from collections import Counter
from gensim.models import Word2Vec
import matplotlib.pyplot as plt
import utils

# %matplotlib inline
# Out:
# 2023-03-01 20:06:27.341302: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Load and display data

with open('../data/countries.json', 'r') as fout:
    countries = json.load(fout)

# %%
countries['India'][:20]
# Out:
# ['India',
#  'Hindi',
#  'Bhārat',
#  'officially',
#  'the',
#  'Republic',
#  'of',
#  'India',
#  'Hindi',
#  'Bhārat',
#  'Gaṇarājya',
#  'is',
#  'a',
#  'country',
#  'in',
#  'South',
#  'Asia',
#  'It',
#  'is',
#  'the']

# %%
print(' '.join(countries['India'])[:512] + ' ...')
# Out:
# India Hindi Bhārat officially the Republic of India Hindi Bhārat Gaṇarājya is a country in South Asia It is the second most populous country the seventh largest country by land area and the most populous democracy in the world Bounded by the Indian Ocean on the south the Arabian Sea on the southwest and the Bay of Bengal on the southeast it shares land borders with Pakistan to the west China Nepal and Bhutan to the north and Bangladesh and Myanmar to the east In the Indian Ocean India is in the vicinity of  ...

# %%
for i, (country, text) in enumerate(countries.items()):
    print(country)
    print(' '.join(text)[:512] + ' ...')
    print('-' * 100)
    if i >= 5:
        break
# Out:
# Afghanistan
# Afghanistan listen Pashto Dari افغانستان Pashto Afġānistān avɣɒnisˈtɒn ab Dari Afġānestān avɣɒnesˈtɒn officially the Islamic Republic of Afghanistan is a mountainous landlocked country at the crossroads of Central and South Asia Afghanistan is bordered by Pakistan to the east and south Iran to the west Turkmenistan Uzbekistan and Tajikistan to the north and China to the northeast Occupying 652 000 square kilometers 252 000 sq mi it is a mountainous country with plains in the north and southwest Kabul is the ...
# ----------------------------------------------------------------------------------------------------
# Albania
# Albania listen a w l BAY nee ə Albanian Shqipëri or Shqipëria officially the Republic of Albania Albanian Republika e Shqipërisë is a country in Southeastern Europe It is located on the Adriatic and Ionian Sea within the Mediterranean Sea and shares land borders with Montenegro to the northwest Kosovo to the northeast North Macedonia to the east Greece to the south and maritime borders with Greece Montenegro and Italy to the west Tirana is its capital and largest city followed by Durrës Vlorë and Shkodër Ge ...
# ----------------------------------------------------------------------------------------------------
# Algeria
# Algeria officially the People s Democratic Republic of Algeria is a country in the Maghreb region of North Africa It is the largest country by total area in Africa and by extension the Arab world and is bordered to the northeast by Tunisia to the east by Libya to the southeast by Niger to the southwest by Mali Mauritania and Western Sahara to the west by Morocco and to the north by the Mediterranean Sea The country has a semi arid geography with most of the population living in the fertile north and the Sah ...
# ----------------------------------------------------------------------------------------------------
# Andorra
# Andorra listen also UK Catalan ənˈdorə officially the Principality of Andorra Catalan Principat d Andorra is a sovereign landlocked microstate on the Iberian Peninsula in the eastern Pyrenees bordered by France to the north and Spain to the south Believed to have been created by Charlemagne Andorra was ruled by the count of Urgell until 988 when it was transferred to the Roman Catholic Diocese of Urgell The present principality was formed by a charter in 1278 It is headed by two co princes the Bishop of Urg ...
# ----------------------------------------------------------------------------------------------------
# Angola
# Angola listen Portuguese ɐ ˈɡɔlɐ officially the Republic of Angola Portuguese República de Angola is a country located on the west coast of Southern Africa It is the second largest lusophone Portuguese speaking country in both total area and population behind Brazil and it is the seventh largest country in Africa bordered by Namibia to the south the Democratic Republic of the Congo to the north Zambia to the east and the Atlantic Ocean to the west Angola has an exclave province the province of Cabinda that  ...
# ----------------------------------------------------------------------------------------------------
# Antigua and Barbuda
# Antigua and Barbuda listen an TEE g w ə bar B Y OO də is a sovereign island country in the West Indies in the Americas lying between the Caribbean Sea and the Atlantic Ocean It consists of two major islands Antigua and Barbuda separated by 63 km 39 mi and smaller islands including Great Bird Green Guiana Long Maiden Prickly Pear York Islands Redonda The permanent population number is about 97 120 2019 est with 97 being resident on Antigua The capital and largest port and city is St John s on Antigua with Co ...
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Basic Word2Vec Usage

# %%
# Create and train a simple model

model = Word2Vec(sentences=countries.values())

# %%
# Check word similarities learnt by the model

model.wv.most_similar('India', topn=5)
# Out:
# [('Brazil', 0.8356989026069641),
#  ('China', 0.8140164017677307),
#  ('Iran', 0.8075459003448486),
#  ('Mozambique', 0.7967085242271423),
#  ('Turkey', 0.7697516679763794)]

# %%
# Enable computation of loss

model = Word2Vec(
    sentences=countries.values(),
    compute_loss=True
)
model.get_latest_training_loss()
# Out:
# 5181355.0

# %% [markdown]
# ### Word2Vec options

# %%
Word2Vec?

# %% [markdown]
# ## Heuristics for Word2vec algorithms

# %% [markdown]
# ### Determining size of the vocabulary

# %%
# How many unique words in the vocabulary?

counter = Counter()
for words in countries.values():
    for word in words:
        counter.update([word])

print(len(counter))
# Out:
# 85125

# %%
# Default vocabulary size of the original model

len(model.wv)
# Out:
# 21092

# %%
# Retrain - increased vocabulary size, more epochs, larger word vectors

metric = utils.MetricCallback(every=1)
model = Word2Vec(
    sentences=countries.values(),
    vector_size=128,
    epochs=10,
    max_vocab_size=65536,
    compute_loss=True,
    callbacks=[metric]
)
plt.plot(metric.myloss)
# Out:
# Loss after epoch 0: 1353837.25
# Loss after epoch 1: 1076362.0
# Loss after epoch 2: 955162.25
# Loss after epoch 3: 887807.5
# Loss after epoch 4: 768290.0
# Loss after epoch 5: 743163.0
# Loss after epoch 6: 725818.0
# Loss after epoch 7: 707261.5
# Loss after epoch 8: 699617.0
# Loss after epoch 9: 654771.5

# %%
# Check similarities again

model.wv.most_similar('India')
# Out:
# [('China', 0.713501513004303),
#  ('Vietnam', 0.6344156861305237),
#  ('Pakistan', 0.6138748526573181),
#  ('Asia', 0.5837562680244446),
#  ('Nigeria', 0.5825437307357788),
#  ('Indonesia', 0.5770354866981506),
#  ('Iran', 0.5734570026397705),
#  ('Nepal', 0.5658297538757324),
#  ('Thailand', 0.5652980804443359),
#  ('Japan', 0.5649046301841736)]

# %%
# Retrain - more epochs

metric = utils.MetricCallback(every=10)
model = Word2Vec(
    sentences=countries.values(),
    vector_size=128,
    epochs=100,
    max_vocab_size=65536,
    compute_loss=True,
    callbacks=[metric],
    min_alpha=0.001,
    workers=9
)
plt.plot(metric.myloss)
# Out:
# Loss after epoch 0: 478237.25
# Loss after epoch 10: 246103.5
# Loss after epoch 20: 227705.0
# Loss after epoch 30: 204666.5
# Loss after epoch 40: 197106.0
# Loss after epoch 50: 182215.0
# Loss after epoch 60: 182447.0
# Loss after epoch 70: 172268.0
# Loss after epoch 80: 165431.0
# Loss after epoch 90: 124074.0

# %%
model.wv.most_similar('India')
# Out:
# [('Nepal', 0.5848039388656616),
#  ('China', 0.5640860199928284),
#  ('Singapore', 0.5541695356369019),
#  ('Pakistan', 0.5491935610771179),
#  ('Bangladesh', 0.5287947654724121),
#  ('Vietnam', 0.5006957650184631),
#  ('Indonesia', 0.467528373003006),
#  ('Bengal', 0.46661245822906494),
#  ('Indian', 0.4642815589904785),
#  ('Malaysia', 0.46117356419563293)]

# %%
# Examine the vector space

X = ['India', 'Pakistan', 'Bangladesh', 'France', 'England', 'Spain']
Y = ['Delhi', 'Islamabad', 'Dhaka', 'Paris', 'London', 'Madrid']
utils.plot_arrows(X, Y, model.wv)

# %%
# Visualize vectors for all countries

utils.plot_vectors(countries, model)
# Out:
# /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %% [markdown]
# ## Word Analogies

# %%
# India: Ganges -> Brazil: __ ?

model.wv.most_similar(positive=['Ganges', 'Brazil'], negative=['India'])
# Out:
# [('river', 0.4572344124317169),
#  ('Lempa', 0.4561925530433655),
#  ('Paraná', 0.4497566819190979),
#  ('Amazon', 0.4308626651763916),
#  ('Plata', 0.4161778390407562),
#  ('Putumayo', 0.41588541865348816),
#  ('Napo', 0.41517871618270874),
#  ('rivers', 0.4146406948566437),
#  ('Río', 0.40634700655937195),
#  ('Esmeraldas', 0.39137518405914307)]

# %%
# America: Washington -> France: __ ?

model.wv.most_similar(positive=['Washington', 'France'], negative=['America'])
# Out:
# [('Paris', 0.42737066745758057),
#  ('London', 0.3995920717716217),
#  ('Arnold', 0.3924475908279419),
#  ('Garibaldi', 0.3922250270843506),
#  ('UK', 0.388365238904953),
#  ('French', 0.3803882896900177),
#  ('Duke', 0.3796524703502655),
#  ('Taylor', 0.3641713559627533),
#  ('1803', 0.35947147011756897),
#  ('Mussolini', 0.35717183351516724)]

# %%
# India: Hindi -> Germany: __ ?

model.wv.most_similar(positive=['Hindi', 'Germany'], negative=['India'])
# Out:
# [('German', 0.463407427072525),
#  ('Edvard', 0.4313614070415497),
#  ('Version', 0.4057869017124176),
#  ('Austrians', 0.4057660698890686),
#  ('Kurt', 0.4006946086883545),
#  ('Georg', 0.3982882797718048),
#  ('Sándor', 0.3903513550758362),
#  ('Gerhard', 0.3866270184516907),
#  ('Leibniz', 0.3808653652667999),
#  ('Österreich', 0.3782944679260254)]

# %%
# Save the model

model.save('wiki-countries.w2v')

# %%
from gensim.models import KeyedVectors
model = KeyedVectors.load('wiki-countries.w2v')

# %%
model
