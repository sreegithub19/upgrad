# %%
# 1.
from IPython.display import display,HTML
import pandas as pd

marks = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/GZVBQG5pzJeNaL1ve50Rv9YNV/class-grades.csv')
print(type(marks))  # <class 'pandas.core.frame.DataFrame'>
'''
To read excel:

marks_xcl = pd.read_excel(...excel file location...)

or

pd.read_excel(..excel file...).to_csv("Test.csv", index = None,header=True)).read_csv()
'''
# Count the number of missing values in each column of the dataset 'marks'.
display(marks.isnull().sum())
#display(marks.isnull().boxplot())
display(marks[:-5])


df = pd.DataFrame(pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/GZVBQG5pzJeNaL1ve50Rv9YNV/class-grades.csv'))
display(df.iloc[0,])  # row-wise
display(df.iloc[:,0]) # column-wise
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Prefix         0
# Assignment     2
# Tutorial      12
# Midterm       16
# TakeHome       9
# Final          5
# dtype: int64
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17    30.00     63.15  48.89
# 3        7       81.22     96.06    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 89       8       97.00    100.52    64.38     90.74  58.61
# 90       8         NaN       NaN      NaN       NaN    NaN
# 91       8       96.41    103.71    56.25     95.93  66.39
# 92       7       95.60     82.28    76.88    108.33  78.33
# 93       8       87.52     91.58    56.25     71.85  85.00
#
# [94 rows x 6 columns]
# Prefix         5.00
# Assignment    57.14
# Tutorial      34.09
# Midterm       64.38
# TakeHome      51.48
# Final         52.50
# Name: 0, dtype: float64
# 7.313131313131313

# %%
# 2. Remove all the rows in the dataset 'marks' having 5 missing values and then print the number of missing values in each column.
import pandas as pd
marks = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/VodvGKvJAaeNrG7kvOQV38aog/class-grades.csv')

#Type your code here to remove rows with missing value equal to 5
marks = marks[marks.isnull().sum(axis=1)<5]
print(marks.isnull().sum())
# Out:
# Prefix         0
# Assignment     0
# Tutorial      10
# Midterm       14
# TakeHome       7
# Final          3
# dtype: int64

# %%
'''3. 
The given data frame 'customer' has a column 'Cust_id' which has values Cust_1, Cust_2 and so on.
Remove the repeated 'Cust_' from the column Cust_id so that the output column Cust_id have just numbers like 1, 2, 3 and so on.
Print the first 10 rows of the dataset  'customer' after processing.
'''

import pandas as pd
customer = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/9B2ZPE1apMvqrLWx7p8ge9dqX/cust_dimen.csv')

customer['Cust_id'] = customer['Cust_id'].apply(lambda x:x[5:])
print(customer.head(10))
# Out:
#         Customer_Name Province   Region Customer_Segment Cust_id
# 0  MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS       1
# 1        BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER       2
# 2       CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE       3
# 3      CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER       4
# 4        CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE       5
# 5      MONICA FEDERLE  NUNAVUT  NUNAVUT        CORPORATE       6
# 6     DOROTHY BADDERS  NUNAVUT  NUNAVUT      HOME OFFICE       7
# 7     NEOLA SCHNEIDER  NUNAVUT  NUNAVUT      HOME OFFICE       8
# 8         CARLOS DALY  NUNAVUT  NUNAVUT      HOME OFFICE       9
# 9       CLAUDIA MINER  NUNAVUT  NUNAVUT   SMALL BUSINESS      10

# %%
'''
4. 
The given Dataframe 'rating' has repeated rows. You need to remove the duplicated rows. 

'''
import pandas as pd
rating = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/JPAqXRWexo7nybkQ7BjPLWVN/rating_final.csv')

display(rating.shape)

updated_rating = rating.drop_duplicates()
display(updated_rating)

updated_rating = rating.drop_duplicates(keep=False)
display(updated_rating)
# Out:
# (1254, 5)
#      userID  placeID  rating  food_rating  service_rating
# 0     U1077   135085       2            2               2
# 1     U1077   135038       2            2               1
# 2     U1077   132825       2            2               2
# 3     U1077   135060       1            2               2
# 4     U1068   135104       1            1               2
# ...     ...      ...     ...          ...             ...
# 1249  U1043   132630       1            1               1
# 1250  U1011   132715       1            1               0
# 1251  U1068   132733       1            1               0
# 1252  U1068   132594       1            1               1
# 1253  U1068   132660       0            0               0
#
# [1149 rows x 5 columns]
#      userID  placeID  rating  food_rating  service_rating
# 0     U1077   135085       2            2               2
# 1     U1077   135038       2            2               1
# 28    U1044   132583       1            2               1
# 29    U1070   132608       2            2               1
# 30    U1070   132609       1            1               1
# ...     ...      ...     ...          ...             ...
# 1249  U1043   132630       1            1               1
# 1250  U1011   132715       1            1               0
# 1251  U1068   132733       1            1               0
# 1252  U1068   132594       1            1               1
# 1253  U1068   132660       0            0               0
#
# [1044 rows x 5 columns]

# %%
'''
5.
'''
# removing outliers (using IQR)
# https://pythonsansar.com/how-to-remove-outliers-in-python-pandas-package/

import seaborn as sns

heart = pd.read_csv('heart.csv')
heart.head(10)

box = sns.boxplot(heart['chol'])

q1 = heart['chol'].quantile(0.25)
q3 = heart['chol'].quantile(0.75)
iqr = q3-q1
lower_limit = q1 - 1.5*iqr
upper_limit = q3 + 1.5*iqr

print(q1,q3,iqr,lower_limit,upper_limit)
little_heart = heart[(heart['chol']>lower_limit) & (heart['chol']<upper_limit)]
little_heart.head(10)
print(heart.shape,little_heart.shape)
# Out:
# 211.0 275.0 64.0 115.0 371.0
# (1025, 14) (1009, 14)
# C:\Users\Padmaja\Anaconda3\envs\newenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
'''
6.
'''
# correlation matrix
print(marks["Assignment"].dtype)
print(marks["Tutorial"].dtype)
print(np.corrcoef(marks["Assignment"],marks["Tutorial"]))


import numpy as np
import matplotlib.pyplot as plt
 
# x represents the age
x = [43, 21, 25, 42, 57, 59]
 
# y represents the glucose level
# corresponding to that age
y = [99, 65, 79, 75, 87, 81]
z = [99, 65, 7, 5, -7, 81]
 
# correlation matrix
matrix = np.corrcoef(x,z)  # max. 2 parameters
print(matrix)
plt.scatter(x,y,z)
plt.show()
plt.scatter(x,y)
plt.show()

plt.show(sns.heatmap(matrix,annot=True))
plt.show(sns.heatmap(matrix,annot=False))

# 3-d correlation

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

x = np.random.rand(20)
y = np.random.rand(20)
z = x*y

fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z,
           linewidths=1, alpha=.7,
           edgecolor='k',
           s = 200,
           c=z)
plt.show()
# Out:
# float64
# float64
# [[nan nan]
#  [nan nan]]
# [[1.         0.02667534]
#  [0.02667534 1.        ]]

# %%
'''
7. The given dataset 'cust_rating' has 3 columns i.e 'rating', ' food_rating', 'service_rating'. Create a new variable 'avg_rating'.

'''

import pandas as pd
cust_rating = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/GvOkzy5MLdy9zJ8vXMArwpRvN/rating_final.csv')

cust_rating['avg_rating'] = round((cust_rating['rating']+cust_rating['food_rating']+cust_rating['service_rating'])/3,3)

print(cust_rating.head(10))
# Out:
#   userID  placeID  rating  food_rating  service_rating  avg_rating
# 0  U1077   135085       2            2               2       2.000
# 1  U1077   135038       2            2               1       1.667
# 2  U1077   132825       2            2               2       2.000
# 3  U1077   135060       1            2               2       1.667
# 4  U1068   135104       1            1               2       1.333
# 5  U1068   132740       0            0               0       0.000
# 6  U1068   132663       1            1               1       1.000
# 7  U1068   132732       0            0               0       0.000
# 8  U1068   132630       1            1               1       1.000
# 9  U1067   132584       2            2               2       2.000

# %%
'''
8.
The given dataset 'order' has a variable 'Order_Date' with the dates of purchase.
Create a new variable 'day' which will contain the day from the date at variable Order_Date.

'''

import pandas as pd
order = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/0gjkvLLgNdQLqG10jo5yyJyjK/orders_dimen.csv')
order['Order_Date'] = pd.to_datetime(order['Order_Date'])
order['Day'] = order['Order_Date'].dt.day
display(order.head(10))
# Out:
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '13-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '28-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '17-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '24-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '26-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '23-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '30-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '25-11-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '14-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '15-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '23-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '21-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '23-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '19-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '28-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '19-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '31-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '30-01-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '29-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '31-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '20-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '20-03-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '21-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '15-01-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '18-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '16-11-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '17-10-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '28-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '29-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '17-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '17-11-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '13-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '16-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '18-08-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '16-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '27-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '23-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '19-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '29-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '17-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '24-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '24-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '19-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '24-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '23-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '15-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '17-01-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '30-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '16-07-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '15-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '23-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '25-01-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '27-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '27-08-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '17-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '16-05-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '22-07-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '18-02-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '27-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '30-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '15-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '14-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '21-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '17-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '16-09-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '22-06-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '28-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '27-07-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '15-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '17-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '22-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '14-11-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '15-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '31-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '29-05-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '18-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '26-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '20-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '28-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '23-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '19-11-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '26-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '29-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '20-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '27-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '29-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '16-01-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '29-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '21-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '21-06-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '26-01-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '19-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '25-09-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '14-01-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '26-08-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '15-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '25-11-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '25-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '26-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '14-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '23-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '24-08-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '23-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '15-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '23-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '16-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '16-01-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '20-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '21-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '24-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '27-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '31-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '17-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '20-08-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '14-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '27-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '15-08-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '14-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '23-10-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '28-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '22-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '13-05-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '29-11-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '21-05-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '27-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '17-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '27-02-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '17-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '23-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '15-10-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '13-03-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '21-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '22-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '21-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '13-07-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '29-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '22-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '30-05-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '21-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '16-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '27-04-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '31-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '19-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '31-03-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '25-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '30-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '17-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '26-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '16-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '13-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '23-11-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '17-02-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '25-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '30-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '16-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '24-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '25-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '31-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '20-02-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '28-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '16-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '24-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '21-02-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '27-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '16-12-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '30-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '29-03-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '13-02-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '28-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '18-05-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '29-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '22-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '16-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '22-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '20-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '25-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '19-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '14-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '25-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '17-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '20-06-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '14-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '30-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# ...
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '13-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '27-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '15-12-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '16-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '28-11-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '25-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '20-07-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '13-08-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '27-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '18-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '13-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '26-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '14-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '28-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '27-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '25-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '26-03-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '29-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '25-01-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '24-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '19-08-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '26-11-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '27-10-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '20-11-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '26-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '21-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '13-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '19-01-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '29-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '28-01-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '18-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '18-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '14-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '13-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '18-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '31-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '14-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '30-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '17-02-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '30-08-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '14-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '17-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '22-09-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '20-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '30-04-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '26-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '15-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '13-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '24-10-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '25-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '25-07-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '20-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '21-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '25-04-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '20-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '27-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '13-11-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_15740\130081196.py:10: UserWarning: Parsing '14-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   order['Order_Date'] = pd.to_datetime(order['Order_Date'])
#    Order_ID Order_Date Order_Priority  Ord_id  Day
# 0         3 2010-10-13            LOW   Ord_1   13
# 1       293 2012-01-10           HIGH   Ord_2   10
# 2       483 2011-10-07           HIGH   Ord_3    7
# 3       515 2010-08-28  NOT SPECIFIED   Ord_4   28
# 4       613 2011-06-17           HIGH   Ord_5   17
# 5       643 2011-03-24           HIGH   Ord_6   24
# 6       678 2010-02-26            LOW   Ord_7   26
# 7       807 2010-11-23         MEDIUM   Ord_8   23
# 8       868 2012-08-06  NOT SPECIFIED   Ord_9    6
# 9       933 2012-04-08  NOT SPECIFIED  Ord_10    8

# %% [markdown]
# ### Pandas practice Udemy

# %%
'''
Important links:
'''
import pandas as pd
import numpy as np
from IPython.display import display , HTML

labels = ['a','b','c']
np_labels = np.array(labels)
print(np.array(labels))

display(HTML('''
<h4>1-d panda series</h4>
'''))
labels = [1,2,3]
np_labels = np.array(labels)
print(pd.Series(data=labels))
print(pd.Series(data=np_labels))
print(pd.Series(data=np_labels,index=labels))

display(HTML('''
<h4>2-d panda series</h4>
'''))
labels = {'a':1,'b':2,'c':3}
print(np.array(labels))
print(pd.Series(data=labels))
print(pd.Series(data=np_labels))
print(pd.Series(data=np_labels,index=labels))

ser1 = pd.Series([1,2,3,4],['Ooty','Kodai','Shimla','Coorg'])
display(ser1 ++--+ ser1.isnull())
display(ser1[::-1][2:])

print(ser1['Ooty'])  # by key
print(ser1[1])  # by index
ser2 = pd.Series([1,2,3,4],['Ooty','Kodai','Shimla','Coorg'])[::-1] # reversing a panda series
#display(ser2)

print(ser1 + ser2)
print(ser1.dtypes)  #int64
ser1 = ser1.astype('float64')
print(ser1.dtypes)  #float64
print(---1**-----ser1[::-1][::-1]**---1**-----1)

df = display(pd.DataFrame(np.random.randn(5,4),['A','B','C','D','E'],['W','X','Y','Z']))
df = pd.DataFrame(np.random.randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])
print(type(df))  # <class 'pandas.core.frame.DataFrame'>



print(df['X'])  # pass column names as keys
df['new'] = df['X']**2
display(df)

df.drop('new',axis=1,inplace=True) # axis=1 -> column, axis=0 -> row
display(df)

df.drop('E',axis=0,inplace=True) # axis=1 -> column, axis=0 -> row
display(df)

df = df.astype("complex64")
df['new'] = df['X']**df['X']
display(df)

df1 = df
display(df1.iloc[2])
display(df1.loc['C']) # == df1.iloc[2]

# all are working
display(df1>0)
display(df1['W']>0)
display(df1[df1['W']>0])
display(df1[df1['W']>0][['Y','X']])
display(df1[df1['W']>0][['X','Y']])
display(df1[df1[df1['W']>0]>0])
display(df1[df1[df1[df1['W']>0]>0]>0])
display(df1[df1[df1[df1[df1['W']>0]>0]>0]>0])

df1 = df
display(df1[(df1['W']<0) | (df1['X']>2)])
display(df1[(df1['W']<0) & (df1['X']<2)])
display(df1)

df1['states'] = 'CA NY LA WT'.split()
display(df1)

# dataframe index hierarchy

outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
display(hier_index)
hier_index = pd.MultiIndex.from_tuples(hier_index)
display(hier_index)

# del df
df = pd.DataFrame(np.random.randn(6,2),hier_index,['A','B'])
display(df)
# Out:
# ['a' 'b' 'c']
# <h4>1-d panda series</h4>
# 0    1
# 1    2
# 2    3
# dtype: int64
# 0    1
# 1    2
# 2    3
# dtype: int32
# 1    1
# 2    2
# 3    3
# dtype: int32
# <h4>2-d panda series</h4>
# {'a': 1, 'b': 2, 'c': 3}
# a    1
# b    2
# c    3
# dtype: int64
# 0    1
# 1    2
# 2    3
# dtype: int32
# a    1
# b    2
# c    3
# dtype: int32
# Ooty      1
# Kodai     2
# Shimla    3
# Coorg     4
# dtype: int64
# Kodai    2
# Ooty     1
# dtype: int64
# 1
# 2
# Coorg     8
# Kodai     4
# Ooty      2
# Shimla    6
# dtype: int64
# int64
# float64
# Ooty     -1.0
# Kodai    -1.0
# Shimla   -1.0
# Coorg    -1.0
# dtype: float64
#           W         X         Y         Z
# A -0.605503 -0.784039  0.832391 -0.975296
# B -1.286280 -0.405612  0.117161  0.522303
# C -0.133015  1.001743  0.130348  1.042394
# D  0.308418 -0.746605  1.440343  0.693897
# E  1.312715  2.162491 -1.083037  0.952157
# <class 'pandas.core.frame.DataFrame'>
# A    0.791662
# B   -0.317572
# C   -0.107386
# D    1.392020
# E    1.597195
# Name: X, dtype: float64
#           W         X         Y         Z       new
# A -0.471035  0.791662 -0.573450  2.469494  0.626728
# B  0.948304 -0.317572  1.192996 -1.043551  0.100852
# C -1.334979 -0.107386 -0.212583  0.273229  0.011532
# D -0.802149  1.392020 -0.623110 -0.827944  1.937720
# E -0.216773  1.597195  1.423166  0.312934  2.551032
#           W         X         Y         Z
# A -0.471035  0.791662 -0.573450  2.469494
# B  0.948304 -0.317572  1.192996 -1.043551
# C -1.334979 -0.107386 -0.212583  0.273229
# D -0.802149  1.392020 -0.623110 -0.827944
# E -0.216773  1.597195  1.423166  0.312934
#           W         X         Y         Z
# A -0.471035  0.791662 -0.573450  2.469494
# B  0.948304 -0.317572  1.192996 -1.043551
# C -1.334979 -0.107386 -0.212583  0.273229
# D -0.802149  1.392020 -0.623110 -0.827944
#                     W                   X                   Y  \
# A -0.471035+0.000000j  0.791662+0.000000j -0.573450+0.000000j
# B  0.948304+0.000000j -0.317572+0.000000j  1.192996+0.000000j
# C -1.334979+0.000000j -0.107386+0.000000j -0.212583+0.000000j
# D -0.802149+0.000000j  1.392020+0.000000j -0.623110+0.000000j
#
#                     Z                 new
# A  2.469494+0.000000j  0.831147+0.000000j
# B -1.043551+0.000000j  0.780552-1.209461j
# C  0.273229+0.000000j  1.199126-0.420621j
# D -0.827945+0.000000j  1.584738+0.000000j
# W     -1.334979+0.000000j
# X     -0.107386+0.000000j
# Y     -0.212583+0.000000j
# Z      0.273229+0.000000j
# new    1.199126-0.420621j
# Name: C, dtype: complex64
# W     -1.334979+0.000000j
# X     -0.107386+0.000000j
# Y     -0.212583+0.000000j
# Z      0.273229+0.000000j
# new    1.199126-0.420621j
# Name: C, dtype: complex64
#        W      X      Y      Z   new
# A  False   True  False   True  True
# B   True  False   True  False  True
# C  False  False  False   True  True
# D  False   True  False  False  True
# A    False
# B     True
# C    False
# D    False
# Name: W, dtype: bool
#                     W                   X                   Y  \
# B  0.948304+0.000000j -0.317572+0.000000j  1.192996+0.000000j
#
#                     Z                 new
# B -1.043551+0.000000j  0.780552-1.209461j
#                     Y                   X
# B  1.192996+0.000000j -0.317572+0.000000j
#                     X                   Y
# B -0.317572+0.000000j  1.192996+0.000000j
#                     W   X                   Y   Z                 new
# A N00000000a00000000N NaN N00000000a00000000N NaN N00000000a00000000N
# B  0.948304+0.000000j NaN  1.192996+0.000000j NaN  0.780552-1.209461j
# C N00000000a00000000N NaN N00000000a00000000N NaN N00000000a00000000N
# D N00000000a00000000N NaN N00000000a00000000N NaN N00000000a00000000N
#                     W   X                   Y   Z                 new
# A N00000000a00000000N NaN N00000000a00000000N NaN N00000000a00000000N
# B  0.948304+0.000000j NaN  1.192996+0.000000j NaN  0.780552-1.209461j
# C N00000000a00000000N NaN N00000000a00000000N NaN N00000000a00000000N
# D N00000000a00000000N NaN N00000000a00000000N NaN N00000000a00000000N
#                     W   X                   Y   Z                 new
# A N00000000a00000000N NaN N00000000a00000000N NaN N00000000a00000000N
# B  0.948304+0.000000j NaN  1.192996+0.000000j NaN  0.780552-1.209461j
# C N00000000a00000000N NaN N00000000a00000000N NaN N00000000a00000000N
# D N00000000a00000000N NaN N00000000a00000000N NaN N00000000a00000000N
#                     W                   X                   Y  \
# A -0.471035+0.000000j  0.791662+0.000000j -0.573450+0.000000j
# C -1.334979+0.000000j -0.107386+0.000000j -0.212583+0.000000j
# D -0.802149+0.000000j  1.392020+0.000000j -0.623110+0.000000j
#
#                     Z                 new
# A  2.469494+0.000000j  0.831147+0.000000j
# C  0.273229+0.000000j  1.199126-0.420621j
# D -0.827945+0.000000j  1.584738+0.000000j
#                     W                   X                   Y  \
# A -0.471035+0.000000j  0.791662+0.000000j -0.573450+0.000000j
# C -1.334979+0.000000j -0.107386+0.000000j -0.212583+0.000000j
# D -0.802149+0.000000j  1.392020+0.000000j -0.623110+0.000000j
#
#                     Z                 new
# A  2.469494+0.000000j  0.831147+0.000000j
# C  0.273229+0.000000j  1.199126-0.420621j
# D -0.827945+0.000000j  1.584738+0.000000j
#                     W                   X                   Y  \
# A -0.471035+0.000000j  0.791662+0.000000j -0.573450+0.000000j
# B  0.948304+0.000000j -0.317572+0.000000j  1.192996+0.000000j
# C -1.334979+0.000000j -0.107386+0.000000j -0.212583+0.000000j
# D -0.802149+0.000000j  1.392020+0.000000j -0.623110+0.000000j
#
#                     Z                 new
# A  2.469494+0.000000j  0.831147+0.000000j
# B -1.043551+0.000000j  0.780552-1.209461j
# C  0.273229+0.000000j  1.199126-0.420621j
# D -0.827945+0.000000j  1.584738+0.000000j
#                     W                   X                   Y  \
# A -0.471035+0.000000j  0.791662+0.000000j -0.573450+0.000000j
# B  0.948304+0.000000j -0.317572+0.000000j  1.192996+0.000000j
# C -1.334979+0.000000j -0.107386+0.000000j -0.212583+0.000000j
# D -0.802149+0.000000j  1.392020+0.000000j -0.623110+0.000000j
#
#                     Z                 new states
# A  2.469494+0.000000j  0.831147+0.000000j     CA
# B -1.043551+0.000000j  0.780552-1.209461j     NY
# C  0.273229+0.000000j  1.199126-0.420621j     LA
# D -0.827945+0.000000j  1.584738+0.000000j     WT
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )
#              A         B
# G1 1 -0.670649  1.236849
#    2  1.554833  0.275935
#    3  0.689972  0.939196
# G2 1 -0.187435  0.259929
#    2 -0.788758  0.932805
#    3  0.102005 -1.488944
